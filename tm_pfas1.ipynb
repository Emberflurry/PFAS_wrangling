# %%
import os

# Topic modeling & clustering
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# Vectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Data handling
import pandas as pd
from pathlib import Path

# Wordcloud & plots
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Optional: nicer plots
plt.rcParams["figure.figsize"] = (10, 6)

# Avoid tokenizer parallelism warnings
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import pandas as pd
import re

# 1) Load the CSV
path = r"C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\lobster_clean2.csv"
df = pd.read_csv(path)

# 2) Clean column names: replace spaces/tabs with "_" and strip non-alphanumeric/underscore
df.columns = df.columns.str.replace(r"[ \t]+", "_", regex=True)
df.columns = df.columns.str.replace(r"[^A-Za-z0-9_]+", "_", regex=True)

# 3) Specific renames (matching your R code)
df = df.rename(columns={
    "_BINARY_Y_N": "ZBINARY_Y_N",
    "_CAT_WHY_YES___how_did_they_deal_with_it_categories_": (
        "ZCAT_WHY_YES___how_did_they_deal_with_it_categories_"
    )
})

# (Optional) sanity check
print(df.shape)
print(df.columns.tolist())
# Out:
# (34, 81)
# ['Timestamp', 'Name', 'Gender', 'Age', 'Town', 'Lobster_Zone', 'Do_you_fish_inshore_or_offshore_', 'Position_on_vessel', 'Type_of_License', 'Number_of_years_lobstering', 'As_a_lobsterman__are_you_concerned_about_pollution__If_yes__what_types_of_pollution_concern_you_most_', 'non_typical', 'subtractnt', 'new', 'As_a_lobsterman__are_you_concerned_about_pollution__If_yes__what_types_of_pollution_concern_you_most_2_MERGED', 'Cleaned_Concat', 'Added_from_next_Q', 'Final_Q1', '_Are_you_aware_of_any_sources_of_pollution_near_your_fishing_grounds_', 'non_typical_1', 'base', 'Cleaned', 'Reconcat', 'Have_you_previously_heard_of_PFAS__also_known_as__forever_chemicals_', '_Do_you_know_if_PFAS_is_an_issue_in_Maine_', '_Do_you_know_if_PFAS_is_an_issue_in_Maine__BINARY', 'When_you_think_about_pollution_in_fisheries__do_you_think_about_PFAS_as_a_pollutant_', '_Do_you_know_if_PFAS_have_been_detected_in_lobsters_', 'Have_you_heard_any_news__research__or_state_communications_about_PFAS_in_lobsters__', 'If_yes_to_the_above_questions__what_source_and_info_', 'Are_you_aware_of_the_human_health_risks_associated_with_PFAS_exposure_', 'Do_you_know_anyone_who_has_been_impacted_by_PFAS__', 'Do_you_know_anyone_who_has_been_impacted_by_PFAS__BINARY', 'How_concerned_are_you_about_PFAS_contamination_in_lobsters_', 'How_concerned_are_you_about_PFAS_negatively_impacting_lobster_health__', 'Do_you_think_PFAS_contamination_could_pose_a_health_risk_to_people_who_eat_lobster__', 'Do_you_think_consumers_would_eat_less_lobster_if_they_learned_of_the_presence_of_PFAS_in_lobsters__', 'Do_you_think_the_exposure_to_PFAS_in_an_area_decreases_the_lobster_population_', 'How_concerned_are_you_about_potential_PFAS_research_negatively_impacting_the_marketability_of_lobster_', 'How_much_trust_do_you_have_in_scientists_', 'What_experiences_have_shaped_your_answer_to_the_previous_question_', 'Would_you_like_there_to_be_research_done_to_monitor_PFAS_levels_in_lobsters__', 'Would_you_want_to_work_with_scientists_who_are_researching_PFAS_in_lobsters_in_the_following_ways_', 'Willing_to_communicate__BINARY', 'How_involved_are_you_with_the_lobster_fishery_co_management_system_', 'In_follow_up_to_the_previous_question__in_what_way_are_you_involved__or_why_are_you_not_involved_', 'How_much_trust_do_you_have_in_state_agencies_to_monitor_and_respond_to_potential_contamination_issues_', 'If_PFAS_were_found_in_your_catch__who_would_you_reach_out_to_for_support__if_anyone__', 'If_PFAS_were_found_in_your_catch__who_would_you_reach_out_to_for_support__if_anyone__CATEGORIZED', 'Unnamed__49', 'Do_you_feel_you_could_voice_concerns_regarding_pollution_to_management__', 'Explain_your_answer_to_the_previous_question', 'If_PFAS_were_detected_in_your_fishing_area_would_you_continue_fishing_in_the_area_', 'If_PFAS_were_detected_in_your_fishing_area_would_you_still_consume_the_lobster_', 'If_PFAS_were_detected_in_your_fishing_area_would_you_still_sell_the_lobster_', 'If_PFAS_were_detected_in_your_fishing_area_would_you_fish_in_a_new_area_', 'If_PFAS_were_detected_in_your_fishing_area_would_you__seek_compensation_or_support_', 'If_PFAS_were_detected_in_your_fishing_area_would_you__lobby_management_to_clean_up_the_source_', 'If_PFAS_were_detected_in_your_fishing_area_would_you__leave_the_fishery_', 'How_easy_would_it_be_to_establish_a_new_fishing_territory_', 'How_dependent_are_you_on_the_lobster_fishery_for_your_livelihood_', 'How_important_is_the_idea_of_passing_down_the_fishery_to_the_next_generation_in_your_family_or_community__Do_concerns_of_potential_PFAS_contamination_affect_how_you_think_about_the_fishery_s_future_for_your_children_or_younger_crew_', 'If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been', 'Lobstermen_have_dealt_with_all_kinds_of_changes_shifts_in_lobster_habitat__right_whale_regulati ...

# %%
# ---- Choose which column is your text variable ----
# For now we're calling it VAR1; later you'll swap in the real name
TEXT_COL = "When_problems_hit_the_lobster_fishery__does_the_community_usually_come_together_to_deal_with_them__If_so__how__Do_you_think_PFAS_issues_would_be_dealt_with_similarly_or_differently_from_other_challenges__In_what_ways_"  # TODO: replace with the actual column name

# Drop missing values in VAR1 and convert to strings
df_text = df.dropna(subset=[TEXT_COL]).copy()
df_text[TEXT_COL] = df_text[TEXT_COL].astype(str)
print("Rows with non-missing VAR1:", df_text.shape[0])
# Final documents list for BERTopic / wordcloud
documents = df_text[TEXT_COL].tolist()
print("Number of documents:", len(documents))
print("Example doc:", documents[0][:200])
# Out:
# Rows with non-missing VAR1: 34
# Number of documents: 34
# Example doc: There's some discourse with strong opinions, but eventually yes. The fishery is unique as there's a lot of collaboration between lobstermen and policy makers. MLA works with a lot of people. Lobsterme

# %%
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# 1) Vectorizer
vectorizer_model = CountVectorizer(
    ngram_range=(1, 3),
    stop_words="english",
    min_df=1  # you can lower this (e.g. 2) if you have fewer responses
)

# 2) UMAP
umap_model = UMAP(
    n_neighbors=20,
    n_components=5,
    metric="cosine",
    random_state=42
)

# 3) HDBSCAN
hdbscan_model = HDBSCAN(
    min_cluster_size=3,
    min_samples=2,
    metric="euclidean",
    prediction_data=True
)

# 4) Representation model
rep_model = KeyBERTInspired()

# 5) BERTopic model
topic_model = BERTopic(
    embedding_model="all-mpnet-base-v2",  # sentence-transformers model
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    calculate_probabilities=True,
    seed_topic_list=None,
    representation_model=rep_model,
    verbose=True,
)

# 6) Fit the model on your lobster text
topics, probs = topic_model.fit_transform(documents)
# Out:
# 2025-11-17 15:07:12,466 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 2/2 [00:04<00:00,  2.48s/it]
# 2025-11-17 15:07:18,637 - BERTopic - Embedding - Completed ✓
# 2025-11-17 15:07:18,637 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-17 15:07:18,702 - BERTopic - Dimensionality - Completed ✓
# 2025-11-17 15:07:18,703 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-17 15:07:18,710 - BERTopic - Cluster - Completed ✓
# 2025-11-17 15:07:18,713 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-17 15:07:20,531 - BERTopic - Representation - Completed ✓

# %%
import os

# Directory where you want to save results
save_dir = r"C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres"
os.makedirs(save_dir, exist_ok=True)

# Model path
model_path = os.path.join(save_dir, "topic_model_python")

# Save the model
topic_model.save(model_path)
print("Model saved to:", model_path)

topic_info = topic_model.get_topic_info()
print(topic_info.head())
print("Number of topics (excluding -1 outlier):", (topic_info.Topic != -1).sum())
# Out:
# 2025-11-17 15:10:27,292 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Model saved to: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_model_python
#    Topic  Count                                               Name  \
# 0     -1     12        -1_pfas_pfas different_know pfas_pfas issue
# 1      0      9  0_yes fishery organizations_background controv...
# 2      1      7  1_pfas dealt differently_pfas_boat races pfas_...
# 3      2      6  2_collaboration lobstermen policy_collaboratio...
#
#                                       Representation  \
# 0  [pfas, pfas different, know pfas, pfas issue, ...
# 1  [yes fishery organizations, background controv...
# 2  [pfas dealt differently, pfas, boat races pfas...
# 3  [collaboration lobstermen policy, collaboratio...
#
#                                  Representative_Docs
# 0  [More often than not. When a fishermen dies ev...
# 1  [Fishermen are fairly resourceful and pretty g...
# 2  [The community comes together with different f...
# 3  [100% the community comes together. In every w...
# Number of topics (excluding -1 outlier): 3

# %%
topic_info = topic_model.get_topic_info()
print(topic_info)
import pandas as pd

pd.Series(topics).value_counts()
# Out:
#    Topic  Count                                               Name  \
# 0     -1     12        -1_pfas_pfas different_know pfas_pfas issue
# 1      0      9  0_yes fishery organizations_background controv...
# 2      1      7  1_pfas dealt differently_pfas_boat races pfas_...
# 3      2      6  2_collaboration lobstermen policy_collaboratio...
#
#                                       Representation  \
# 0  [pfas, pfas different, know pfas, pfas issue, ...
# 1  [yes fishery organizations, background controv...
# 2  [pfas dealt differently, pfas, boat races pfas...
# 3  [collaboration lobstermen policy, collaboratio...
#
#                                  Representative_Docs
# 0  [More often than not. When a fishermen dies ev...
# 1  [Fishermen are fairly resourceful and pretty g...
# 2  [The community comes together with different f...
# 3  [100% the community comes together. In every w...
# -1    12
#  0     9
#  1     7
#  2     6
# Name: count, dtype: int64

# %%
topic_info = topic_model.get_topic_info()
print(topic_info)
# Make sure indices line up
df_text = df_text.reset_index(drop=True)

# Attach topic assignments
df_topics_docs = df_text.copy()
df_topics_docs["Topic"] = topics

# Quick peek: a few docs per topic
for t in sorted(set(topics)):
    if t == -1:
        continue  # skip outliers
    print("\n=== Topic", t, "===")
    print(topic_model.get_topic(t))  # top words for this topic
    print(df_topics_docs.loc[df_topics_docs["Topic"] == t, TEXT_COL].head(5))
# Out:
#    Topic  Count                                               Name  \
# 0     -1     12        -1_pfas_pfas different_know pfas_pfas issue
# 1      0      9  0_yes fishery organizations_background controv...
# 2      1      7  1_pfas dealt differently_pfas_boat races pfas_...
# 3      2      6  2_collaboration lobstermen policy_collaboratio...
#
#                                       Representation  \
# 0  [pfas, pfas different, know pfas, pfas issue, ...
# 1  [yes fishery organizations, background controv...
# 2  [pfas dealt differently, pfas, boat races pfas...
# 3  [collaboration lobstermen policy, collaboratio...
#
#                                  Representative_Docs
# 0  [More often than not. When a fishermen dies ev...
# 1  [Fishermen are fairly resourceful and pretty g...
# 2  [The community comes together with different f...
# 3  [100% the community comes together. In every w...
#
# === Topic 0 ===
# [('yes fishery organizations', np.float32(0.5618259)), ('background controversial pfas', np.float32(0.46422175)), ('change frustrating fishermen', np.float32(0.42634642)), ('fishery', np.float32(0.4023866)), ('pfas dealt similarly', np.float32(0.39274028)), ('pfas', np.float32(0.3876337)), ('lobstermen', np.float32(0.3820344)), ('pfas dealt differently', np.float32(0.37314862)), ('trying fishermen work', np.float32(0.33509773)), ('trying fishermen', np.float32(0.31957513))]
# 10    Fishermen are fairly resourceful and pretty go...
# 12    Historically no, but now everyone is on the te...
# 15    He wants to say yes, but trying to get fisherm...
# 18    There's nothing the fishermen can really do. I...
# 22    the community comes together when problems hit...
# Name: When_problems_hit_the_lobster_fishery__does_the_community_usually_come_together_to_deal_with_them__If_so__how__Do_you_think_PFAS_issues_would_be_dealt_with_similarly_or_differently_from_other_challenges__In_what_ways_, dtype: object
#
# === Topic 1 ===
# [('pfas dealt differently', np.float32(0.5521193)), ('pfas', np.float32(0.5377924)), ('boat races pfas', np.float32(0.5109585)), ('unaware uneducated pfas', np.float32(0.49278462)), ('assistance pfas', np.float32(0.45977676)), ('assistance pfas dealt', np.float32(0.4372296)), ('coming pfas dealt', np.float32(0.42601946)), ('pfas dealt', np.float32(0.4083022)), ('board figure pfas', np.float32(0.370852)), ('events dinners lobster', np.float32(0.3146362))]
# 1     Referred back to when communities came togethe...
# 4     Yes, and pfas dealt with similarly, the commun...
# 13    Yes, everyone is on board to figure out. PFAS ...
# 21    The community comes together with different fu...
# 26    The community usually comes together. There's ...
# Name: When_problems_hit_the_lobster_fishery__does_the_community_usually_come_together_to_deal_with_them__If_so__how__Do_you_think_PFAS_issues_would_be_dealt_with_similarly_or_differently_from_other_challenges__In_what_ways_, dtype: object
#
# === Topic 2 ===
# [('collaboration lobstermen policy', np.float32(0.64834607)), ('collaboration lobstermen', np.float32(0.5273681)), ('come fishermen rally', np.float32(0.5230182)), ('advocate pfas dealt', np.float32(0.51557374)), ('pfas', np.float32(0.51055574)), ('communities pfas', np.float32(0.5069471)), ('communities pfas feels', np.float32(0.4892286)), ('come lobstermen independent', np.float32(0.48259658)), ('community come lobstermen', np.float32(0.44412872)), ('right whale situation', np.float32(0.40570185))]
# 0     There's some discourse with strong opinions, b...
# 6     Only if it's really dire does the community co...
# 7     It would be similar to other issues. It's not ...
# 14    He feels the community comes together. Local c...
# 16    100% the community comes together. In every wa...
# Name: When_problems_hit_the_lobster_fishery__does_the_community_usually_come_together_to_deal_with_them__If_so__how__Do_you_think_PFAS_issues_would_be_dealt_with_similarly_or_differently_from_other_challenges__In_what_ways_, dtype: object

# %%
import pandas as pd
import os

# Get topic info
topic_info = topic_model.get_topic_info()
print(topic_info)

# Option A: exclude outlier topic -1 (what we did before)
valid_topic_ids = topic_info[topic_info.Topic != -1].Topic.tolist()

# Option B: include -1 as well for debugging:
# valid_topic_ids = topic_info.Topic.tolist()

topics_data = []

for topic_id in valid_topic_ids:
    topic = topic_model.get_topic(topic_id)
    if topic is None:
        continue
    for word, weight in topic:
        topics_data.append((topic_id, word, weight))

topics_df = pd.DataFrame(topics_data, columns=["Topic", "Word", "Weight"])
print(topics_df.head())
print("Number of rows in topics_df:", len(topics_df))

csv_path = os.path.join(save_dir, "topic_keywords_2.csv")
topics_df.to_csv(csv_path, index=False)
print("Topic keyword CSV saved to:", csv_path)
# Out:
#    Topic  Count                                               Name  \
# 0     -1     12        -1_pfas_pfas different_know pfas_pfas issue
# 1      0      9  0_yes fishery organizations_background controv...
# 2      1      7  1_pfas dealt differently_pfas_boat races pfas_...
# 3      2      6  2_collaboration lobstermen policy_collaboratio...
#
#                                       Representation  \
# 0  [pfas, pfas different, know pfas, pfas issue, ...
# 1  [yes fishery organizations, background controv...
# 2  [pfas dealt differently, pfas, boat races pfas...
# 3  [collaboration lobstermen policy, collaboratio...
#
#                                  Representative_Docs
# 0  [More often than not. When a fishermen dies ev...
# 1  [Fishermen are fairly resourceful and pretty g...
# 2  [The community comes together with different f...
# 3  [100% the community comes together. In every w...
#    Topic                           Word    Weight
# 0      0      yes fishery organizations  0.561826
# 1      0  background controversial pfas  0.464222
# 2      0   change frustrating fishermen  0.426346
# 3      0                        fishery  0.402387
# 4      0           pfas dealt similarly  0.392740
# Number of rows in topics_df: 30
# Topic keyword CSV saved to: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_keywords_2.csv

# %%
from bertopic import BERTopic

model_path = os.path.join(save_dir, "topic_model_python")
topic_model = BERTopic.load(model_path)
print("Model loaded from:", model_path)
# Out:
# Model loaded from: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_model_python

# %%
import pandas as pd

# Get topic info and exclude the outlier topic -1
topic_info = topic_model.get_topic_info()
valid_topic_ids = topic_info[topic_info.Topic != -1].Topic.tolist()

topics_data = []

for topic_id in valid_topic_ids:
    # Each topic is a list of (word, weight) tuples
    topic = topic_model.get_topic(topic_id)
    for word, weight in topic:
        topics_data.append((topic_id, word, weight))

topics_df = pd.DataFrame(topics_data, columns=["Topic", "Word", "Weight"])
print(topics_df.head())

# Save to CSV in your tmres folder
csv_path = os.path.join(save_dir, "topic_keywords_2.csv")
topics_df.to_csv(csv_path, index=False)
print("Topic keyword CSV saved to:", csv_path)
# Out:
#    Topic                           Word    Weight
# 0      0      yes fishery organizations  0.561826
# 1      0  background controversial pfas  0.464222
# 2      0   change frustrating fishermen  0.426346
# 3      0                        fishery  0.402387
# 4      0           pfas dealt similarly  0.392740
# Topic keyword CSV saved to: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_keywords_2.csv

# %%
#TODO FIX BROKEN
# Simple topic overview
topic_model.visualize_topics()
# Out:
# C:\Users\John DeForest\AppData\Roaming\Python\Python313\site-packages\umap\spectral.py:519: RuntimeWarning: k >= N for N * N square matrix. Attempting to use scipy.linalg.eigh instead.
#   eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Simple topic overview
# ----> 2 topic_model.visualize_topics()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bertopic\_bertopic.py:2442, in BERTopic.visualize_topics(self, topics, top_n_topics, use_ctfidf, custom_labels, title, width, height)
#    2409 """Visualize topics, their sizes, and their corresponding words.
#    2410
#    2411 This visualization is highly inspired by LDAvis, a great visualization
#    (...)   2439 ```
#    2440 """
#    2441 check_is_fitted(self)
# -> 2442 return plotting.visualize_topics(
#    2443     self,
#    2444     topics=topics,
#    2445     top_n_topics=top_n_topics,
#    2446     use_ctfidf=use_ctfidf,
#    2447     custom_labels=custom_labels,
#    2448     title=title,
#    2449     width=width,
#    2450     height=height,
#    2451 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\bertopic\plotting\_topics.py:102, in visualize_topics(topic_model, topics, top_n_topics, use_ctfidf, custom_labels, title, width, height)
#      98         embeddings = UMAP(n_neighbors=2, n_components=2, metric="hellinger", random_state=42).fit_transform(
#      99             embeddings
#     100         )
#     101     else:
# --> 102         embeddings = UMAP(n_neighbors=2, n_components=2, metric="cosine", random_state=42).fit_transform(embeddings)
#     103 else:
#     104     raise ModuleNotFoundError(
#     105         "UMAP is required to reduce the embeddings.. Please install it using `pip install umap-learn`."
#     106     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\umap_.py:2935, in UMAP.fit_transform(self, X, y, ensure_all_finite, **kwargs)
#    2897 def fit_transform(self, X, y=None, ensure_all_finite=True, **kwargs):
#    2898     """Fit X into an embedded space and return that transformed
#    2899     output.
#    2900
#    (...)   2933         Local radii of data points in the embedding (log-transformed).
#    2934     """
# -> 2935     self.fit(X, y, ensure_all_finite, **kwargs)
#    2936     if self.transform_mode == "embedding":
#    2937         if self.output_dens:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\umap_.py:2817, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
#    2821         random_state,  # JH why raw data?
#    2822         **kwargs,
#    2823     )
#    2825     if self.n_epochs_list is not None:
#    2826         if "embedding_list" not in aux_data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\umap_.py:2872, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state, **kwargs)
#    2867 def _fit_embed_data(self, X, n_epochs, init, random_state, **kwargs):
#    2868     """A method wrapper for simplicial_set_embedding that can be
#    2869     replaced by subclasses. Arbitrary keyword arguments can be passed
#    2870     through .fit() and .fit_transform().
#    2871     """
# -> 2872     return simplicial_set_embedding(
#    2873         X,
#    2874         self.graph_,
#    2875         self.n_components,
#    2876         self._initial_alpha,
#    2877         self._a,
#    2878         self._b,
#    2879         self.repulsion_strength,
#    2880         self.negative_sample_rate,
#    2881         n_epochs,
#    2882         init,
#    2883         random_state,
#    2884         self._input_distance_func,
#    2885         self._metric_kwds,
#    2886         self.densmap,
#    2887         self._densmap_kwds,
#    2888         self.output_dens,
#    2889         self._output_distance_func,
#    2890         self._output_metric_kwds,
#    2891         self.output_metric in ("euclidean", "l2"),
#    2892         self.random_state is None,
#    2893         self.verbose,
#    2894         tqdm_kwds=self.tqdm_kwds,
#    2895     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\umap_.py:1109, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1105     embedding = noisy_scale_coords(
#    1106         embedding, random_state, max_coord=10, noise=0.0001
#    1107     )
#    1108 elif isinstance(init, str) and init == "spectral":
# -> 1109     embedding = spectral_layout(
#    1110         data,
#    1111         graph,
#    1112         n_components,
#    1113         random_state,
#    1114         metric=metric,
#    1115         metric_kwds=metric_kwds,
#    1116     )
#    1117     # We add a little noise to avoid local minima for optimization to come
#    1118     embedding = noisy_scale_coords(
#    1119         embedding, random_state, max_coord=10, noise=0.0001
#    1120     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)    271     maxiter=0,
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)    302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter,
#     314     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\umap\spectral.py:519, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     516 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     518 if method == "eigsh":
# --> 519     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     520         L,
#     521         k,
#     522         which="SM",
#     523         ncv=num_lanczos_vectors,
#     524         tol=tol or 1e-4,
#     525         v0=np.ones(L.shape[0]),
#     526         maxiter=maxiter or graph.shape[0] * 5,
#     527     )
#     528 elif method == "lobpcg":
#     529     with warnings.catch_warnings():
#
# File ~\AppData\Roaming\Python\Python313\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1612, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1607 warnings.warn("k >= N for N * N square matrix. "
#    1608               "Attempting to use scipy.linalg.eigh instead.",
#    1609               RuntimeWarning, stacklevel=2)
#    1611 if issparse(A):
# -> 1612     raise TypeError("Cannot use scipy.linalg.eigh for sparse A with "
#    1613                     "k >= N. Use scipy.linalg.eigh(A.toarray()) or"
#    1614                     " reduce k.")
#    1615 if isinstance(A, LinearOperator):
#    1616     raise TypeError("Cannot use scipy.linalg.eigh for LinearOperator "
#    1617                     "A with k >= N.")
#
# TypeError: Cannot use scipy.linalg.eigh for sparse A with k >= N. Use scipy.linalg.eigh(A.toarray()) or reduce k.

# %%
# Hierarchical topic visualization
topic_model.visualize_hierarchy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hoverinfo': 'text',
#               'marker': {'color': 'rgb(61,153,112)'},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAAAA6oW9/fhXrPzqhb39+Fes/AAAAAAAAAAA=', 'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AAAAAAAALsAAAAAAAAAuwAAAAAAAADnAAAAAAAAAOcA=', 'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'text',
#               'marker': {'color': 'rgb(61,153,112)'},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAAADXTRlEiCLsP9dNGUSIIuw/OqFvf34V6z8=', 'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AAAAAAAAFMAAAAAAAAAUwAAAAAAAADTAAAAAAAAANMA=', 'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'autosize': False,
#                'height': 245,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'hovermode': 'closest',
#                'plot_bgcolor': '#ECEFF1',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': '<b>Hierarchical Clustering</b>',
#                          'x': 0.5,
#                          'xanchor': 'center',
#                          'yanchor': 'top'},
#                'width': 1000,
#                'xaxis': {'mirror': 'allticks',
#                          'rangemode': 'tozero',
#                          'showgrid': False,
#                          'showline': True,
#                          'showticklabels': True,
#                          'ticks': 'outside',
#                          'type': 'linear',
#                          'zeroline': False},
#                'yaxis': {'mirror': 'allticks',
#                          'range': [-30.0, 0.0],
#                          'rangemode': 'tozero',
#                          'showgrid': False,
#                          'showline': True,
#                          'showticklabels': True,
#                          'tickmode': 'array',
#                          'ticks': 'outside',
#                          'ticktext': [1_pfas dealt differently_pf..., 0_yes
#                                       fishery organizations..., 2_collaboration
#                                       lobstermen ...],
#                          'tickvals': [-5.0, -15.0, -25.0],
#                          'type': 'linear',
#                          'zeroline': False}}
# })

# %%
# Hierarchical topic structure + tree
hierarchical_topics = topic_model.hierarchical_topics(documents)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# .
# ├─■──pfas dealt differently_pfas_boat races pfas_unaware uneducated pfas_assistance pfas ── Topic: 1
# └─yes fishery_lobstermen_fishery_pfas dealt similarly_pfas
#      ├─■──yes fishery organizations_background controversial pfas_change frustrating fishermen_fishery_pfas de ── Topic: 0
#      └─■──collaboration lobstermen policy_collaboration lobstermen_come fishermen rally_advocate pfas dealt_pf ── Topic: 2

# %%
#by age: 
import numpy as np

# Make sure Age is numeric; coerce errors to NaN
df_text["Age"] = pd.to_numeric(df_text["Age"], errors="coerce")

# Keep only rows with non-missing Age
df_age = df_text.dropna(subset=["Age"]).reset_index(drop=True)

# Documents and "time" variable (here: Age)
documents_age = df_age[TEXT_COL].astype(str).tolist()
ages = df_age["Age"].astype(float).tolist()

print(f"Number of documents with Age: {len(documents_age)}")
print(f"Example Age values: {ages[:10]}")
# Out:
# Number of documents with Age: 34
# Example Age values: [24.0, 24.0, 28.0, 73.0, 26.0, 52.0, 27.0, 24.0, 26.0, 33.0]

# %%
# Use the existing trained topic_model
updated_topics, _ = topic_model.transform(documents_age)
# Out:
# Batches: 100%|██████████| 2/2 [00:07<00:00,  3.62s/it]
# 2025-11-17 15:16:00,363 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-11-17 15:16:00,366 - BERTopic - Dimensionality - Completed ✓
# 2025-11-17 15:16:00,369 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-11-17 15:16:00,373 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2025-11-17 15:16:00,383 - BERTopic - Probabilities - Completed ✓
# 2025-11-17 15:16:00,386 - BERTopic - Cluster - Completed ✓

# %%
topics_over_time = topic_model.topics_over_time(
    documents_age,
    ages,
    updated_topics
)

fig = topic_model.visualize_topics_over_time(
    topics_over_time,
    title="Topics Across Age"
)
fig
# Out:
# 23it [00:27,  1.20s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hoverinfo': 'text',
#               'hovertext': [<b>Topic 0</b><br>Words: whale issues really, team
#                             fishermen realized, fishermen realized, right whale
#                             issues, whale issues, <b>Topic 0</b><br>Words:
#                             lobstermen pfas, know lobstermen pfas, lobstermen pfas
#                             unless, fishery threatening people, fishery
#                             threatening, <b>Topic 0</b><br>Words: right whales
#                             pfas, fishermen really, whales pfas, whales pfas dealt,
#                             fishermen, <b>Topic 0</b><br>Words: pfas uncontrollable
#                             fishery, fishery control going, fishery control,
#                             uncontrollable fishery control, meeting pfas, <b>Topic
#                             0</b><br>Words: listen fisheries policy, fisheries
#                             policy general, fisheries policy, general societal
#                             issue, pfas, <b>Topic 0</b><br>Words: trying fishermen
#                             work, fishermen work like, fishermen work, trying
#                             fishermen, fake news lobstermen, <b>Topic
#                             0</b><br>Words: yes fishery organizations, threatened
#                             fishermen left, fishery organizations, fishery
#                             organizations community, yes fishery, <b>Topic
#                             0</b><br>Words: island housing community, island
#                             housing, housing organization inspired, community land,
#                             community association buys],
#               'marker': {'color': '#E69F00'},
#               'mode': 'lines',
#               'name': '0_yes fishery organizations_background c...',
#               'type': 'scatter',
#               'x': {'bdata': ('AAAAAAAAPEAAAAAAAABAQAAAAAAAAE' ... 'AAAE1AAAAAAABAUUAAAAAAAEBTQA=='),
#                     'dtype': 'f8'},
#               'y': {'bdata': 'AQIBAQEBAQE=', 'dtype': 'i1'}},
#              {'hoverinfo': 'text',
#               'hovertext': [<b>Topic 1</b><br>Words: uneducated pfas community,
#                             pfas, communities casco bay, regarding pfas, pfas dealt
#                             differently, <b>Topic 1</b><br>Words: pfas dealt
#                             similarly, pfas dealt differently, regarding pfas, pfas
#                             different, yes pfas, <b>Topic 1</b><br>Words:
#                             association nonprofit, nonprofit, association nonprofit
#                             rich, funds regarding pfas, nonprofit rich, <b>Topic
#                             1</b><br>Words: pfas dealt similar, pfas dealt
#                             differently, regarding pfas, pfas, regarding pfas
#                             process, <b>Topic 1</b><br>Words: pfas dealt
#                             differently, regarding pfas, pfas, unaware uneducated
#                             pfas, uneducated pfas, <b>Topic 1</b><br>Words:
#                             emerging contaminate, pfas dealt differently, regarding
#                             pfas, financial assistance pfas, unknown emerging
#                             contaminate],
#               'marker': {'color': '#56B4E9'},
#               'mode': 'lines',
#               'name': '1_pfas dealt differently_pfas_boat races...',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAOEAAAAAAAAA6QAAAAAAAAD1AAAAAAAAAQUAAAAAAAABEQAAAAAAAAFFA', 'dtype': 'f8'},
#               'y': {'bdata': 'AQIBAQEB', 'dtype': 'i1'}},
#              {'hoverinfo': 'text',
#               'hovertext': [<b>Topic 2</b><br>Words: collaboration lobstermen
#                             policy, lobstermen policy makers, issues fishermen
#                             noticed, lobstermen policy, issues fishermen, <b>Topic
#                             2</b><br>Words: lobstermen independent, come lobstermen
#                             independent, lobstermen independent really, community
#                             come lobstermen, lobstermen, <b>Topic 2</b><br>Words:
#                             lobster fishery sustainability, fishery sustainability
#                             island, important lobster fishery, lobster fishery,
#                             understanding important lobster, <b>Topic
#                             2</b><br>Words: lobstermen resourceful, social ties
#                             pfas, lobstermen came raised, fiber lobstermen
#                             resourceful, lobstermen, <b>Topic 2</b><br>Words: say
#                             pfas lobsters, pfas lobsters, lobster iconic maine, yes
#                             lobster iconic, yes lobster],
#               'marker': {'color': '#009E73'},
#               'mode': 'lines',
#               'name': '2_collaboration lobstermen policy_collab...',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAOEAAAAAAAAA7QAAAAAAAgEdAAAAAAAAATkAAAAAAAEBSQA==', 'dtype': 'f8'},
#               'y': {'bdata': 'AgEBAQE=', 'dtype': 'i1'}}],
#     'layout': {'height': 450,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'legend': {'title': {'text': '<b>Global Topic Representation'}},
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': 'Topics Across Age',
#                          'x': 0.4,
#                          'xanchor': 'center',
#                          'y': 0.95,
#                          'yanchor': 'top'},
#                'width': 1250,
#                'xaxis': {'showgrid': True},
#                'yaxis': {'showgrid': True, 'title': {'text': 'Frequency'}}}
# })

# %%
#NOW NEXT COL FOR TOPIC MODEL
# Text column for this run
TEXT_COL = "If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been"

# Drop missing values and convert to string
df_text = df.dropna(subset=[TEXT_COL]).copy()
df_text[TEXT_COL] = df_text[TEXT_COL].astype(str)

print("Rows with non-missing text:", df_text.shape[0])

# Final documents list for BERTopic
documents = df_text[TEXT_COL].tolist()
print("Number of documents:", len(documents))
print("Example doc:", documents[0][:200])
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# 1) Vectorizer
vectorizer_model = CountVectorizer(
    ngram_range=(1, 2),
    stop_words="english",
    min_df=1
)

# 2) UMAP (slightly more permissive)
umap_model = UMAP(
    n_neighbors=10,
    n_components=2,
    metric="cosine",
    random_state=42
)

# 3) HDBSCAN (allow small clusters)
hdbscan_model = HDBSCAN(
    min_cluster_size=3,
    min_samples=1,
    metric="euclidean",
    prediction_data=True
)

# 4) Representation model
rep_model = KeyBERTInspired()

# 5) BERTopic model
topic_model = BERTopic(
    embedding_model="all-mpnet-base-v2",
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    calculate_probabilities=True,
    seed_topic_list=None,
    representation_model=rep_model,
    verbose=True,
)

# 6) Fit the model on this specific question column
topics, probs = topic_model.fit_transform(documents)
# Out:
# 2025-11-17 15:29:49,116 - BERTopic - Embedding - Transforming documents to embeddings.
# Rows with non-missing text: 34
# Number of documents: 34
# Example doc: Lobstermen would not want to share territory. would be difficult because you have permitting for your zone.
# Batches: 100%|██████████| 2/2 [00:04<00:00,  2.23s/it]
# 2025-11-17 15:29:54,846 - BERTopic - Embedding - Completed ✓
# 2025-11-17 15:29:54,847 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-17 15:29:54,964 - BERTopic - Dimensionality - Completed ✓
# 2025-11-17 15:29:54,967 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-17 15:29:54,980 - BERTopic - Cluster - Completed ✓
# 2025-11-17 15:29:54,989 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-17 15:29:57,401 - BERTopic - Representation - Completed ✓

# %%
import os

save_dir = r"C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres"
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, "topic_model_python")
topic_model.save(model_path)
print("Model saved to:", model_path)

topic_info = topic_model.get_topic_info()
print(topic_info)
print("Number of topics (excluding -1 outlier):", (topic_info.Topic != -1).sum())
# Out:
# 2025-11-17 15:29:59,044 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Model saved to: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_model_python
#    Topic  Count                                               Name  \
# 0      0     13  0_lobstermen territorial_lobstermen want_idea ...
# 1      1     11  1_lobstermen_areas lobsters_lobstering_fished ...
# 2      2      7  2_accommodate fishermen_fish areas_declining t...
# 3      3      3  3_territory fish_ocean people_fish lot_need te...
#
#                                       Representation  \
# 0  [lobstermen territorial, lobstermen want, idea...
# 1  [lobstermen, areas lobsters, lobstering, fishe...
# 2  [accommodate fishermen, fish areas, declining ...
# 3  [territory fish, ocean people, fish lot, need ...
#
#                                  Representative_Docs
# 0  [Lobstermen would not be open to sharing terri...
# 1  [A lot of people wouldn't move traps at all ev...
# 2  [If guys move gear into a new area, then that ...
# 3  [In the casco Bay Area everyone gets along wel...
# Number of topics (excluding -1 outlier): 4

# %%
# Make indices line up
df_text = df_text.reset_index(drop=True)

df_topics_docs = df_text.copy()
df_topics_docs["Topic"] = topics

# Peek a few responses per topic
for t in sorted(set(topics)):
    if t == -1:
        continue
    print("\n=== Topic", t, "===")
    print(topic_model.get_topic(t))  # top words
    print(df_topics_docs.loc[df_topics_docs["Topic"] == t, TEXT_COL].head(5))
# Out:
# === Topic 0 ===
# [('lobstermen territorial', np.float32(0.73900753)), ('lobstermen want', np.float32(0.580724)), ('idea lobstermen', np.float32(0.5513441)), ('congested lobstermen', np.float32(0.5468248)), ('sharing territory', np.float32(0.53033584)), ('closed lobstermen', np.float32(0.47580245)), ('lobstermen', np.float32(0.4694628)), ('lobstermen open', np.float32(0.46236873)), ('establish territory', np.float32(0.39327785)), ('thinks lobsters', np.float32(0.39134493))]
# 0    Lobstermen would not want to share territory. ...
# 1    Lobstermen would not be open to sharing territ...
# 4    Lobstermen are very territorial, and would not...
# 6    Nope. Not willingly. Lobstermen are very compe...
# 7    cause a lot of social and physical issues. lob...
# Name: If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been, dtype: object
#
# === Topic 1 ===
# [('lobstermen', np.float32(0.5661366)), ('areas lobsters', np.float32(0.53878653)), ('lobstering', np.float32(0.49399)), ('fished area', np.float32(0.42302835)), ('fish area', np.float32(0.368555)), ('fishing grounds', np.float32(0.34962487)), ('fishing', np.float32(0.34590933)), ('sharing territory', np.float32(0.311306)), ('traps', np.float32(0.23873022)), ('territory', np.float32(0.23656401))]
# 2     It would be challenging. If we were forced int...
# 3     It could cause gear conflict. Gear conflicts a...
# 9     It would create pressure on the areas not affe...
# 10    It would be really hard. If you're saying a sm...
# 12    If you congest an area then there becomes a lo...
# Name: If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been, dtype: object
#
# === Topic 2 ===
# [('accommodate fishermen', np.float32(0.41226172)), ('fish areas', np.float32(0.40548167)), ('declining territory', np.float32(0.37075427)), ('established territory', np.float32(0.36622941)), ('territory', np.float32(0.34357396)), ('traps peoples', np.float32(0.315346)), ('bomb fishery', np.float32(0.31390774)), ('fishery cut', np.float32(0.3126418)), ('peoples traps', np.float32(0.2953565)), ('fishes inshore', np.float32(0.26738018))]
# 5                            No way anyone is sharing.
# 8     No one is going to share. People got shot and ...
# 19    No one is going to be open to sharing. It's co...
# 20    He knows a friend who moved his traps to off t...
# 22    Everyone is so territorial. Where he fishes ha...
# Name: If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been, dtype: object
#
# === Topic 3 ===
# [('territory fish', np.float32(0.4427172)), ('ocean people', np.float32(0.3841523)), ('fish lot', np.float32(0.3268694)), ('need territory', np.float32(0.3115027)), ('people fish', np.float32(0.289701)), ('territory', np.float32(0.28755066)), ('big ocean', np.float32(0.2796648)), ('fish', np.float32(0.26243752)), ('ocean', np.float32(0.258941)), ('guys wouldn', np.float32(0.24641672))]
# 11    There would be a lot of animosity, unless they...
# 14    In the casco Bay Area everyone gets along well...
# 18    Some guys wouldn't move unless they were force...
# Name: If_PFAS_was_detected_in_some_areas__but_not_in_other_areas__how_would_that_affect_the_social_dynamics_of_the_fishery_How_territorial_would_other_lobstermen_be_Do_you_think_lobstermen_would_be_open_to_allowing_lobstermen_whose_fishing_grounds_have_been, dtype: object

# %%
import pandas as pd

topic_info = topic_model.get_topic_info()
print(topic_info)

# Exclude outlier topic -1
valid_topic_ids = topic_info[topic_info.Topic != -1].Topic.tolist()

topics_data = []

for topic_id in valid_topic_ids:
    topic = topic_model.get_topic(topic_id)
    if topic is None:
        continue
    for word, weight in topic:
        topics_data.append((topic_id, word, weight))

topics_df = pd.DataFrame(topics_data, columns=["Topic", "Word", "Weight"])
print(topics_df.head())
print("Number of rows in topics_df:", len(topics_df))

csv_path = os.path.join(save_dir, "topic_keywords_3.csv")
topics_df.to_csv(csv_path, index=False)
print("Topic keyword CSV saved to:", csv_path)
# Out:
#    Topic  Count                                               Name  \
# 0      0     13  0_lobstermen territorial_lobstermen want_idea ...
# 1      1     11  1_lobstermen_areas lobsters_lobstering_fished ...
# 2      2      7  2_accommodate fishermen_fish areas_declining t...
# 3      3      3  3_territory fish_ocean people_fish lot_need te...
#
#                                       Representation  \
# 0  [lobstermen territorial, lobstermen want, idea...
# 1  [lobstermen, areas lobsters, lobstering, fishe...
# 2  [accommodate fishermen, fish areas, declining ...
# 3  [territory fish, ocean people, fish lot, need ...
#
#                                  Representative_Docs
# 0  [Lobstermen would not be open to sharing terri...
# 1  [A lot of people wouldn't move traps at all ev...
# 2  [If guys move gear into a new area, then that ...
# 3  [In the casco Bay Area everyone gets along wel...
#    Topic                    Word    Weight
# 0      0  lobstermen territorial  0.739008
# 1      0         lobstermen want  0.580724
# 2      0         idea lobstermen  0.551344
# 3      0    congested lobstermen  0.546825
# 4      0       sharing territory  0.530336
# Number of rows in topics_df: 40
# Topic keyword CSV saved to: C:\Users\John DeForest\Desktop\dWrangl\PFAS project phoebe\tmres\topic_keywords_3.csv

# %%
# Simple topic overview (interactive Plotly)
topic_model.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'customdata': array([[0,
#                                     'lobstermen territorial | lobstermen want | idea lobstermen | congested lobstermen | sharing territory',
#                                     13],
#                                    [1,
#                                     'lobstermen | areas lobsters | lobstering | fished area | fish area',
#                                     11],
#                                    [2,
#                                     'accommodate fishermen | fish areas | declining territory | established territory | territory',
#                                     7],
#                                    [3,
#                                     'territory fish | ocean people | fish lot | need territory | people fish',
#                                     3]], dtype=object),
#               'hovertemplate': '<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}',
#               'legendgroup': '',
#               'marker': {'color': '#B0BEC5',
#                          'line': {'color': 'DarkSlateGrey', 'width': 2},
#                          'size': {'bdata': 'DQsHAw==', 'dtype': 'i1'},
#                          'sizemode': 'area',
#                          'sizeref': 0.008125,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': 'v8yOQdqIjUHraZFBF8CGQQ==', 'dtype': 'f4'},
#               'xaxis': 'x',
#               'y': {'bdata': 'QCiDQLeBoUCQkmFAUReiQA==', 'dtype': 'f4'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': 'D1',
#                                 'x': np.float32(14.3172245),
#                                 'y': np.float32(4.4105167),
#                                 'yshift': 10},
#                                {'showarrow': False,
#                                 'text': 'D2',
#                                 'x': np.float32(17.610226),
#                                 'xshift': 10,
#                                 'y': np.float32(5.825148)}],
#                'height': 650,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'legend': {'itemsizing': 'constant', 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'shapes': [{'line': {'color': '#CFD8DC', 'width': 2},
#                            'type': 'line',
#                            'x0': np.float32(17.610226),
#                            'x1': np.float32(17.610226),
#                            'y0': np.float32(2.995885),
#                            'y1': np.float32(5.825148)},
#                           {'line': {'color': '#9E9E9E', 'width': 2},
#                            'type': 'line',
#                            'x0': np.float32(14.3172245),
#                            'x1': np.float32(20.903225),
#                            'y0': np.float32(4.4105167),
#                            'y1': np.float32(4.4105167)}],
#                'sliders': [{'active': 0,
#                             'pad': {'t': 50},
#                             'steps': [{'args': [{'marker.color': [['red', '#B0BEC5', '#B0BEC5', '#B0BEC5']]}],
#                                        'label': 'Topic 0',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5', 'red', '#B0BEC5', '#B0BEC5']]}],
#                                        'label': 'Topic 1',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5', '#B0BEC5', 'red', '#B0BEC5']]}],
#                                        'label': 'Topic 2',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5', '#B0BEC5', '#B0BEC5', 'red']]}],
#                                        'label': 'Topic 3',
#                                        'method': 'update'}]}],
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': '<b>Intertopic Distance Map</b>',
#                          'x': 0.5,
#                          'xanchor': 'center',
#                          'y': 0.95,
#                          'yanchor': 'top'},
#                'width': 650,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [14.317224502563477, 20.90322494506836],
#                          'title': {'text': ''},
#                          'visible': False},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'range': [2.995884895324707, 5.825148105621338],
#                          'title': {'text': ''},
#                          'visible': False}}
# })

# %%
# Hierarchical topic structure
hierarchical_topics = topic_model.hierarchical_topics(documents)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)

# Hierarchical visualization
topic_model.visualize_hierarchy()
# Out:
# 100%|██████████| 3/3 [00:04<00:00,  1.53s/it]
# .
# ├─■──territory fish_ocean people_fish lot_need territory_people fish ── Topic: 3
# └─lobstermen territorial_lobstermen want_idea lobstermen_lobstermen open_lobstermen
#      ├─■──accommodate fishermen_fish areas_declining territory_established territory_territory ── Topic: 2
#      └─lobstermen territorial_lobstermen want_idea lobstermen_lobstermen open_willingly lobstermen
#           ├─■──lobstermen_areas lobsters_lobstering_fished area_fish area ── Topic: 1
#           └─■──lobstermen territorial_lobstermen want_idea lobstermen_congested lobstermen_sharing territory ── Topic: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hoverinfo': 'text',
#               'marker': {'color': 'rgb(61,153,112)'},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAAAAIXewAFxPpPwhd7AAXE+k/AAAAAAAAAAA=', 'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AAAAAAAAOcAAAAAAAAA5wAAAAAAAgEHAAAAAAACAQcA=', 'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'text',
#               'marker': {'color': 'rgb(61,153,112)'},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAAACHZ4u3kVTrP4dni7eRVOs/CF3sABcT6T8=', 'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AAAAAAAALsAAAAAAAAAuwAAAAAAAAD7AAAAAAAAAPsA=', 'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'text',
#               'marker': {'color': 'rgb(61,153,112)'},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAAACvxFEMdQbtP6/EUQx1Bu0/h2eLt5FU6z8=', 'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AAAAAAAAFMAAAAAAAAAUwAAAAAAAgDbAAAAAAACANsA=', 'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'autosize': False,
#                'height': 260,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'hovermode': 'closest',
#                'plot_bgcolor': '#ECEFF1',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': '<b>Hierarchical Clustering</b>',
#                          'x': 0.5,
#                          'xanchor': 'center',
#                          'yanchor': 'top'},
#                'width': 1000,
#                'xaxis': {'mirror': 'allticks',
#                          'rangemode': 'tozero',
#                          'showgrid': False,
#                          'showline': True,
#                          'showticklabels': True,
#                          'ticks': 'outside',
#                          'type': 'linear',
#                          'zeroline': False},
#                'yaxis': {'mirror': 'allticks',
#                          'range': [-40.0, 0.0],
#                          'rangemode': 'tozero',
#                          'showgrid': False,
#                          'showline': True,
#                          'showticklabels': True,
#                          'tickmode': 'array',
#                          'ticks': 'outside',
#                          'ticktext': [3_territory fish_ocean peop...,
#                                       2_accommodate fishermen_fis...,
#                                       1_lobstermen_areas lobsters..., 0_lobstermen
#                                       territorial_lo...],
#                          'tickvals': [-5.0, -15.0, -25.0, -35.0],
#                          'type': 'linear',
#                          'zeroline': False}}
# })

# %%
import numpy as np

# Ensure numeric Age
df_text["Age"] = pd.to_numeric(df_text["Age"], errors="coerce")

df_age = df_text.dropna(subset=["Age"]).reset_index(drop=True)

documents_age = df_age[TEXT_COL].astype(str).tolist()
ages = df_age["Age"].astype(float).tolist()

print(f"Number of documents with Age: {len(documents_age)}")
print(f"Example Age values: {ages[:10]}")

updated_topics, _ = topic_model.transform(documents_age)

topics_over_time = topic_model.topics_over_time(
    documents_age,
    ages,
    updated_topics
)

fig = topic_model.visualize_topics_over_time(
    topics_over_time,
    title="Topics Across Age"
)
fig
# Out:
# Number of documents with Age: 34
# Example Age values: [24.0, 24.0, 28.0, 73.0, 26.0, 52.0, 27.0, 24.0, 26.0, 33.0]
# Batches: 100%|██████████| 2/2 [00:04<00:00,  2.15s/it]
# 2025-11-17 15:31:08,858 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-11-17 15:31:08,860 - BERTopic - Dimensionality - Completed ✓
# 2025-11-17 15:31:08,862 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-11-17 15:31:08,866 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2025-11-17 15:31:08,876 - BERTopic - Probabilities - Completed ✓
# 2025-11-17 15:31:08,878 - BERTopic - Cluster - Completed ✓
# 23it [00:21,  1.08it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hoverinfo': 'text',
#               'hovertext': [<b>Topic 0</b><br>Words: lobstermen territorial,
#                             lobstermen want, issues lobstermen, idea lobstermen,
#                             shit lobstermen, <b>Topic 0</b><br>Words: lobstermen
#                             territorial, lobstermen want, problems lobstermen, shit
#                             lobstermen, idea lobstermen, <b>Topic 0</b><br>Words:
#                             lobstermen territorial, lobstermen want, willingly
#                             lobstermen, lobstermen competitive, lobstermen cut,
#                             <b>Topic 0</b><br>Words: lobstermen territorial,
#                             lobstermen want, idea lobstermen, lobstermen sharing,
#                             lobsters valuable, <b>Topic 0</b><br>Words: congested
#                             lobstermen, lobstermen territorial, lobstermen want,
#                             idea lobstermen, problems lobstermen, <b>Topic
#                             0</b><br>Words: lobstermen territorial, lobstermen
#                             want, lobstermen willing, idea lobstermen, negatively
#                             lobstermen, <b>Topic 0</b><br>Words: lobstermen
#                             territorial, lobstermen want, problems lobstermen, idea
#                             lobstermen, lobstermen, <b>Topic 0</b><br>Words: boats
#                             sunk, cut boats, boats, lines cut, sunk lobstermen,
#                             <b>Topic 0</b><br>Words: lobstermen territorial,
#                             lobstermen territorially, lobstermen want, problems
#                             lobstermen, lobstermen, <b>Topic 0</b><br>Words:
#                             lobstermen territorial, lobstermen want, idea
#                             lobstermen, lobstermen open, sharing fishing, <b>Topic
#                             0</b><br>Words: lobstermen territorial, lobstermen
#                             want, lobstermen open, idea lobstermen, lobstermen
#                             receptive],
#               'marker': {'color': '#E69F00'},
#               'mode': 'lines',
#               'name': '0_lobstermen territorial_lobstermen want...',
#               'type': 'scatter',
#               'x': {'bdata': ('AAAAAAAAOEAAAAAAAAA6QAAAAAAAAD' ... 'AAAE9AAAAAAACAUEAAAAAAAABRQA=='),
#                     'dtype': 'f8'},
#               'y': {'bdata': 'AwEBAQEBAQEBAQE=', 'dtype': 'i1'}},
#              {'hoverinfo': 'text',
#               'hovertext': [<b>Topic 1</b><br>Words: moving traps, territorial
#                             lobstermen, territory lobstermen, traps areas, traps,
#                             <b>Topic 1</b><br>Words: sharing territory, territorial
#                             stuff, forgiving territorial, territory, conflicts,
#                             <b>Topic 1</b><br>Words: moving traps, 200 traps,
#                             traps, traps drama, big spill, <b>Topic 1</b><br>Words:
#                             people displaced, displaced people, territory affect,
#                             territory increase, sharing territory, <b>Topic
#                             1</b><br>Words: allowing lobstermen, areas lobsters,
#                             lobstermen jobs, lobstermen fishing, contaminated zone,
#                             <b>Topic 1</b><br>Words: sharing territory, gear
#                             conflicts, territorial stuff, territory affect,
#                             territorial probably, <b>Topic 1</b><br>Words:
#                             lobstermen zone, areas lobsters, territory lobstermen,
#                             contaminated area, lobstermen dependent, <b>Topic
#                             1</b><br>Words: monoculture lobstering, areas lobsters,
#                             lobstering goes, fishing contaminated, lobsters aren,
#                             <b>Topic 1</b><br>Words: gear conflicts, gear conflict,
#                             conflict gear, cause gear, conflicts bad, <b>Topic
#                             1</b><br>Words: contaminated areas, contaminated area,
#                             vs contaminated, contaminated, pristine vs],
#               'marker': {'color': '#56B4E9'},
#               'mode': 'lines',
#               'name': '1_lobstermen_areas lobsters_lobstering_f...',
#               'type': 'scatter',
#               'x': {'bdata': ('AAAAAAAAOkAAAAAAAAA8QAAAAAAAAD' ... 'AAAABNQAAAAAAAQFJAAAAAAABAU0A='),
#                     'dtype': 'f8'},
#               'y': {'bdata': 'AQIBAQEBAQEBAQ==', 'dtype': 'i1'}},
#              {'hoverinfo': 'text',
#               'hovertext': [<b>Topic 2</b><br>Words: swan island, freeport,
#                             battles freeport, freeport little, island swan,
#                             <b>Topic 2</b><br>Words: territorial fishes, fishes
#                             inshore, currently fishes, fishes declining, fish,
#                             <b>Topic 2</b><br>Words: accommodate fishermen, fished
#                             acceptance, fish areas, fishermen fish, fishermen,
#                             <b>Topic 2</b><br>Words: sharing, share, way sharing,
#                             share people, sharing going, <b>Topic 2</b><br>Words:
#                             guys fish, fishes, fish challenged, fish, territorial
#                             fishes, <b>Topic 2</b><br>Words: fishery cut, territory
#                             fish, fishery, bomb fishery, traps isle],
#               'marker': {'color': '#009E73'},
#               'mode': 'lines',
#               'name': '2_accommodate fishermen_fish areas_decli...',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAOkAAAAAAAABAQAAAAAAAAEVAAAAAAAAASkAAAAAAAEBRQAAAAAAAQFJA', 'dtype': 'f8'},
#               'y': {'bdata': 'AQECAQEB', 'dtype': 'i1'}},
#              {'hoverinfo': 'text',
#               'hovertext': [<b>Topic 3</b><br>Words: moving, industry
#                             accommodating, people moving, moving good, friction
#                             people, <b>Topic 3</b><br>Words: territory fish, need
#                             territory, bay area, new areas, casco bay, <b>Topic
#                             3</b><br>Words: lot animosity, animosity unless, people
#                             fish, territory fish, animosity],
#               'marker': {'color': '#F0E442'},
#               'mode': 'lines',
#               'name': '3_territory fish_ocean people_fish lot_n...',
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAAREAAAAAAAIBHQAAAAAAAAExA', 'dtype': 'f8'},
#               'y': {'bdata': 'AQEB', 'dtype': 'i1'}}],
#     'layout': {'height': 450,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'legend': {'title': {'text': '<b>Global Topic Representation'}},
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': 'Topics Across Age',
#                          'x': 0.4,
#                          'xanchor': 'center',
#                          'y': 0.95,
#                          'yanchor': 'top'},
#                'width': 1250,
#                'xaxis': {'showgrid': True},
#                'yaxis': {'showgrid': True, 'title': {'text': 'Frequency'}}}
# })
